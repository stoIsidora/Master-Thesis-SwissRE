# %%
import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker 
from xgboost import XGBClassifier
from sklearn.inspection import partial_dependence
import random
import os

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sksurv.preprocessing import OneHotEncoder
from sklearn_pandas import DataFrameMapper

import torch
import torch.nn as nn
import torchtuples as tt

from torchtuples.callbacks import EarlyStopping
from sklearn.neural_network import MLPClassifier
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import log_loss
from sklearn.metrics import brier_score_loss

# %%
df_train = pd.read_csv('df_train.csv')
df_test = pd.read_csv('df_test.csv')

# %%
df_train, df_val = train_test_split(df_train, test_size=0.2, random_state=42)

# %%
# det dummy
dummy_f = ['REGION','MARST', 'RACEA', 'USBORN', 'HSTATYR', 'ALCSTAT1', 'SMOKESTATUS2']
df_train = pd.get_dummies(df_train, columns=dummy_f, prefix=dummy_f).astype(int)
df_val = pd.get_dummies(df_val, columns=dummy_f, prefix=dummy_f).astype(int)
df_test = pd.get_dummies(df_test, columns=dummy_f, prefix=dummy_f).astype(int)

# %%
# list of columns to standardize
cols_stand = ['AGE', 'BMICALC', 'HRSLEEP']
              
cols_norm = ['FAMSIZE', 'EDUCREC1', 'POVERTY', 'FSRAWSCORE', 'ALC5UPYR', 'ALCAMT', 'ALCDAYSYR',
              'CIGSDAY', 'MOD10DMIN', 'MOD10FWK', 'VIG10DMIN', 'VIG10FWK', 'STRONGFWK', 'AEFFORT', 
              'AFEELINT1MO', 'AWORTHLESS', 'WRYMEDCST', 'WRYRET',
              'SEX', 'HINOTCOVE', 'HIPRIVATEE', 'HIMCAIDE', 'HIMCAREE', 'ARTHGLUPEV',
              'BLIND', 'CANCEREV', 'CHEARTDIEV', 'CPOXEV', 'DIABETICEV', 'EMPHYSEMEV',
              'HEARTATTEV', 'HEARTCONEV', 'HYPERTENEV', 'KIDNEYWKYR', 'LIVERCHRON',
              'LIVERCONYR', 'STROKEV']

# list of columns not to standardize
cols_leave = [col for col in df_train.columns if col not in cols_stand + cols_norm + ['TIMETOEVENT', 'MORTSTAT']]

# create mapper entries
standardize = [([col], StandardScaler()) for col in cols_stand]
normalize = [([col], MinMaxScaler()) for col in cols_norm]
leave = [(col, None) for col in cols_leave]

# combine into one mapper
x_mapper = DataFrameMapper(standardize + normalize + leave, df_out=False)

# prepare X matrices
x_train = df_train.drop(columns=['MORTSTAT', 'TIMETOEVENT'])
x_val = df_val.drop(columns=['MORTSTAT', 'TIMETOEVENT'])
x_test = df_test.drop(columns=['MORTSTAT', 'TIMETOEVENT'])

# %%
# transform with DataFrameMapper and convert to PyTorch tensors
x_train = torch.tensor(x_mapper.fit_transform(df_train.drop(columns=['MORTSTAT', 'TIMETOEVENT'])), dtype=torch.float32)
x_val = torch.tensor(x_mapper.transform(df_val.drop(columns=['MORTSTAT', 'TIMETOEVENT'])), dtype=torch.float32)
x_test = torch.tensor(x_mapper.transform(df_test.drop(columns=['MORTSTAT', 'TIMETOEVENT'])), dtype=torch.float32)

# %%
# define three-year mortality status as PyTorch tensors
y_train = torch.tensor(np.where((df_train["MORTSTAT"] == 1) & (df_train["TIMETOEVENT"] <= 3), 1, 0), dtype=torch.float32).view(-1, 1)
y_val = torch.tensor(np.where((df_val["MORTSTAT"] == 1) & (df_val["TIMETOEVENT"] <= 3), 1, 0), dtype=torch.float32).view(-1, 1)
y_test = torch.tensor(np.where((df_test["MORTSTAT"] == 1) & (df_test["TIMETOEVENT"] <= 3), 1, 0), dtype=torch.float32).view(-1, 1)

# %%
# define loss funtions
def ll3y(estimator, X, y_df):
    try:
        death_p = torch.sigmoid(estimator.predict(X))

        # check for NaNs in predictions
        if torch.isnan(death_p).any():
            print("NaNs in prediction — assigning score = -100")
            return -100.0
        
        # otherwise return log_loss
        return -log_loss(y_df, death_p)
    
    except Exception as e:
        print(f"Error during scoring: {e} — assigning score = -100")
        return -100.0
    

def bs3y(estimator, X, y_df):
    try:
        death_p = torch.sigmoid(estimator.predict(X))

        # check for NaNs in predictions
        if torch.isnan(death_p).any():
            print("NaNs in prediction — assigning score = -100")
            return -100.0
        
        # otherwise return log_loss
        return -brier_score_loss(y_df, death_p)
    
    except Exception as e:
        print(f"Error during scoring: {e} — assigning score = -100")
        return -100.0

# %%
# GridSearchCV

# %%
# set seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(SEED)


# define parameter grid
param_grid = {'batch_size': [200, 400, 800],
              'epochs': [30, 60], 
              'lr': [0.001,0.005, 0.01],
              'dropout': [0.0, 0.2, 0.5],
              'num_nodes': [[32, 16], [32], [16]]}

param_combos = list(product(param_grid['batch_size'], param_grid['epochs'], param_grid['lr'], param_grid['dropout'], param_grid['num_nodes']))



# compute cross-validation loss for each combination of hyperparatmers
n_splits = 4
results_ll = []
results_bs = []

for i, (batch_size, epochs, lr, dropout, num_nodes) in enumerate(param_combos):
    print(f"\n=== Grid {i+1}/{len(param_combos)}:  batch_size={batch_size},  epochs={epochs}, lr={lr}, dropout={dropout}, nodes={num_nodes} ===")

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    scores_ll = []
    scores_bs = []

    for fold, (train_idx, tst_idx) in enumerate(kf.split(x_train)):
        print(f"  Fold {fold + 1}/{n_splits}")
        
        x_tr, x_tst = x_train[train_idx], x_train[tst_idx]
        y_tr, y_tst = y_train[train_idx], y_train[tst_idx]
        
        # define architecure
        in_features = x_tr.shape[1]
        net = tt.practical.MLPVanilla(in_features, num_nodes, 1, activation=nn.ReLU, dropout=dropout)
        # define model
        loss_fn = nn.BCEWithLogitsLoss()
        model = tt.Model(net, loss_fn, tt.optim.Adam)  
        model.optimizer.set_lr(lr) 
        # for early stopping
        checkpoint_path = 'local_checkpoints0.pt'
        if os.path.exists(checkpoint_path):
            os.remove(checkpoint_path)
        callbacks = [EarlyStopping(patience=20, file_path=checkpoint_path)]
        
        # fit model
        model.fit(x_tr, y_tr, batch_size=batch_size, epochs=epochs, val_data=(x_val, y_val), shuffle=True, verbose=False, callbacks=callbacks)
        
        # compute loss
        score_ll = ll3y(model, x_tst, y_tst)
        scores_ll.append(score_ll)
        score_bs = bs3y(model, x_tst, y_tst)
        scores_bs.append(score_bs)
        print(f"    LL is: {-score_ll:.4f}")
        print(f"    BS is: {-score_bs:.4f}")
    # save mean loss vales
    mean_score_ll = np.mean(scores_ll)
    std_score_ll = np.std(scores_ll)
    mean_score_bs = np.mean(scores_bs)
    std_score_bs = np.std(scores_bs)
    results_ll.append({'batch_size': batch_size, 'epochs': epochs, 'lr': lr, 'dropout': dropout,
                    'num_nodes': str(num_nodes), 'mean_neg_logloss': mean_score_ll, 'std_neg_logloss': std_score_ll})
    results_bs.append({'batch_size': batch_size, 'epochs': epochs, 'lr': lr, 'dropout': dropout,
                    'num_nodes': str(num_nodes), 'mean_neg_logloss': mean_score_bs, 'std_neg_logloss': std_score_bs})
# Out:
# === Grid 1/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1169
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1154
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1274
#     BS is: 0.0333
#   Fold 4/4
#     LL is: 0.1117
#     BS is: 0.0290
#
# === Grid 2/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1152
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1141
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1228
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0284
#
# === Grid 3/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0283
#
# === Grid 4/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1132
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1238
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1086
#     BS is: 0.0284
#
# === Grid 5/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1217
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0288
#
# === Grid 6/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1092
#     BS is: 0.0285
#
# === Grid 7/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1155
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1243
#     BS is: 0.0332
#   Fold 4/4
#     LL is: 0.1122
#     BS is: 0.0293
#
# === Grid 8/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1159
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1178
#     BS is: 0.0296
#
# === Grid 9/162:  batch_size=200,  epochs=30, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1142
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0288
#
# === Grid 10/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1152
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1142
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1247
#     BS is: 0.0325
#   Fold 4/4
#     LL is: 0.1105
#     BS is: 0.0290
#
# === Grid 11/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1141
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1106
#     BS is: 0.0286
#
# === Grid 12/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1144
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1135
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1239
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1094
#     BS is: 0.0285
#
# === Grid 13/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1125
#     BS is: 0.0297
#   Fold 2/4
#     LL is: 0.1155
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1244
#     BS is: 0.0327
#   Fold 4/4
#     LL is: 0.1132
#     BS is: 0.0295
#
# === Grid 14/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1144
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1129
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0284
#
# === Grid 15/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1128
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1121
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1261
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1109
#     BS is: 0.0289
#
# === Grid 16/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1117
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1226
#     BS is: 0.0327
#   Fold 4/4
#     LL is: 0.1147
#     BS is: 0.0298
#
# === Grid 17/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1130
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1118
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1199
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0288
#
# === Grid 18/162:  batch_size=200,  epochs=30, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1203
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0286
#
# === Grid 19/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1144
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1142
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1206
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0288
#
# === Grid 20/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1138
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1135
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1238
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1121
#     BS is: 0.0291
#
# === Grid 21/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1143
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0289
#
# === Grid 22/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0284
#
# === Grid 23/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1130
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1228
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1116
#     BS is: 0.0292
#
# === Grid 24/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1129
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0287
#
# === Grid 25/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1090
#     BS is: 0.0284
#
# === Grid 26/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1124
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1208
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1084
#     BS is: 0.0284
#
# === Grid 27/162:  batch_size=200,  epochs=30, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1197
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0287
#
# === Grid 28/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1162
#     BS is: 0.0304
#   Fold 2/4
#     LL is: 0.1152
#     BS is: 0.0307
#   Fold 3/4
#     LL is: 0.1230
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1113
#     BS is: 0.0285
#
# === Grid 29/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1153
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1151
#     BS is: 0.0306
#   Fold 3/4
#     LL is: 0.1265
#     BS is: 0.0328
#   Fold 4/4
#     LL is: 0.1104
#     BS is: 0.0288
#
# === Grid 30/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1152
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1146
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1227
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1108
#     BS is: 0.0286
#
# === Grid 31/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1150
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1239
#     BS is: 0.0325
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0286
#
# === Grid 32/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1147
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0285
#
# === Grid 33/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1118
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1199
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0287
#
# === Grid 34/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1174
#     BS is: 0.0308
#   Fold 2/4
#     LL is: 0.1119
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1280
#     BS is: 0.0338
#   Fold 4/4
#     LL is: 0.1143
#     BS is: 0.0297
#
# === Grid 35/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1129
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1195
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0288
#
# === Grid 36/162:  batch_size=200,  epochs=60, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1152
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0285
#
# === Grid 37/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1163
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1140
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1278
#     BS is: 0.0330
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0290
#
# === Grid 38/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1197
#     BS is: 0.0307
#   Fold 2/4
#     LL is: 0.1157
#     BS is: 0.0305
#   Fold 3/4
#     LL is: 0.1211
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1116
#     BS is: 0.0290
#
# === Grid 39/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1158
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1164
#     BS is: 0.0306
#   Fold 3/4
#     LL is: 0.1218
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0286
#
# === Grid 40/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0284
#
# === Grid 41/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1146
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1153
#     BS is: 0.0306
#   Fold 3/4
#     LL is: 0.1203
#     BS is: 0.0316
#   Fold 4/4
#     LL is: 0.1097
#     BS is: 0.0286
#
# === Grid 42/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1120
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1087
#     BS is: 0.0284
#
# === Grid 43/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1136
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1202
#     BS is: 0.0316
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0287
#
# === Grid 44/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1104
#     BS is: 0.0289
#
# === Grid 45/162:  batch_size=200,  epochs=60, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0286
#
# === Grid 46/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1150
#     BS is: 0.0307
#   Fold 3/4
#     LL is: 0.1233
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1117
#     BS is: 0.0290
#
# === Grid 47/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1106
#     BS is: 0.0288
#
# === Grid 48/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0297
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0284
#
# === Grid 49/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1143
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0286
#
# === Grid 50/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1108
#     BS is: 0.0289
#
# === Grid 51/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1094
#     BS is: 0.0285
#
# === Grid 52/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1128
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1107
#     BS is: 0.0292
#
# === Grid 53/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1121
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1105
#     BS is: 0.0288
#
# === Grid 54/162:  batch_size=200,  epochs=60, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1136
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1206
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0289
#
# === Grid 55/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1179
#     BS is: 0.0306
#   Fold 2/4
#     LL is: 0.1156
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1230
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1126
#     BS is: 0.0289
#
# === Grid 56/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1162
#     BS is: 0.0305
#   Fold 2/4
#     LL is: 0.1146
#     BS is: 0.0305
#   Fold 3/4
#     LL is: 0.1222
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0284
#
# === Grid 57/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1147
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1128
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0286
#
# === Grid 58/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1138
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1159
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1113
#     BS is: 0.0288
#
# === Grid 59/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1120
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0287
#
# === Grid 60/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1128
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1129
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0286
#
# === Grid 61/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1163
#     BS is: 0.0305
#   Fold 2/4
#     LL is: 0.1151
#     BS is: 0.0305
#   Fold 3/4
#     LL is: 0.1238
#     BS is: 0.0330
#   Fold 4/4
#     LL is: 0.1134
#     BS is: 0.0297
#
# === Grid 62/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0288
#
# === Grid 63/162:  batch_size=400,  epochs=30, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1206
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1112
#     BS is: 0.0291
#
# === Grid 64/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1202
#     BS is: 0.0312
#   Fold 2/4
#     LL is: 0.1146
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1216
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1103
#     BS is: 0.0287
#
# === Grid 65/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1145
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1175
#     BS is: 0.0310
#   Fold 3/4
#     LL is: 0.1208
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1157
#     BS is: 0.0296
#
# === Grid 66/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1151
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1141
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1108
#     BS is: 0.0286
#
# === Grid 67/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1165
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0286
#
# === Grid 68/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1131
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0284
#
# === Grid 69/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1136
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1128
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0284
#
# === Grid 70/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1131
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1140
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1223
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1094
#     BS is: 0.0287
#
# === Grid 71/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1103
#     BS is: 0.0287
#
# === Grid 72/162:  batch_size=400,  epochs=30, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1116
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1234
#     BS is: 0.0325
#   Fold 4/4
#     LL is: 0.1109
#     BS is: 0.0291
#
# === Grid 73/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1138
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1237
#     BS is: 0.0325
#   Fold 4/4
#     LL is: 0.1109
#     BS is: 0.0292
#
# === Grid 74/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1149
#     BS is: 0.0306
#   Fold 3/4
#     LL is: 0.1216
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1138
#     BS is: 0.0297
#
# === Grid 75/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1223
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1105
#     BS is: 0.0287
#
# === Grid 76/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1129
#     BS is: 0.0297
#   Fold 2/4
#     LL is: 0.1124
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1088
#     BS is: 0.0284
#
# === Grid 77/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1119
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1090
#     BS is: 0.0285
#
# === Grid 78/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1136
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1199
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0285
#
# === Grid 79/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1126
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1213
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1085
#     BS is: 0.0284
#
# === Grid 80/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1130
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1217
#     BS is: 0.0323
#   Fold 4/4
#     LL is: 0.1086
#     BS is: 0.0283
#
# === Grid 81/162:  batch_size=400,  epochs=30, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1121
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0287
#
# === Grid 82/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1202
#     BS is: 0.0308
#   Fold 2/4
#     LL is: 0.1150
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1222
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1107
#     BS is: 0.0287
#
# === Grid 83/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1171
#     BS is: 0.0309
#   Fold 2/4
#     LL is: 0.1138
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1236
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1108
#     BS is: 0.0288
#
# === Grid 84/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1146
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1134
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0287
#
# === Grid 85/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1148
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1204
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0288
#
# === Grid 86/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1087
#     BS is: 0.0284
#
# === Grid 87/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1131
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1099
#     BS is: 0.0287
#
# === Grid 88/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1181
#     BS is: 0.0309
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1133
#     BS is: 0.0294
#
# === Grid 89/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1143
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1126
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1236
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0283
#
# === Grid 90/162:  batch_size=400,  epochs=60, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1144
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1211
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0288
#
# === Grid 91/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1143
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1227
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1144
#     BS is: 0.0292
#
# === Grid 92/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1158
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1194
#     BS is: 0.0311
#   Fold 3/4
#     LL is: 0.1225
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1120
#     BS is: 0.0290
#
# === Grid 93/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1134
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1225
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0287
#
# === Grid 94/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1231
#     BS is: 0.0327
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0286
#
# === Grid 95/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1176
#     BS is: 0.0305
#   Fold 2/4
#     LL is: 0.1130
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1241
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0286
#
# === Grid 96/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1121
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0286
#
# === Grid 97/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1219
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0287
#
# === Grid 98/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1127
#     BS is: 0.0297
#   Fold 2/4
#     LL is: 0.1120
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1199
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1088
#     BS is: 0.0284
#
# === Grid 99/162:  batch_size=400,  epochs=60, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1126
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0285
#
# === Grid 100/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1140
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1222
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1098
#     BS is: 0.0287
#
# === Grid 101/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1145
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1104
#     BS is: 0.0288
#
# === Grid 102/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1146
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1130
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1102
#     BS is: 0.0288
#
# === Grid 103/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1121
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0290
#
# === Grid 104/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1197
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1099
#     BS is: 0.0287
#
# === Grid 105/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1135
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1084
#     BS is: 0.0283
#
# === Grid 106/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1124
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1110
#     BS is: 0.0291
#
# === Grid 107/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1111
#     BS is: 0.0297
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1083
#     BS is: 0.0284
#
# === Grid 108/162:  batch_size=400,  epochs=60, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1136
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1117
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1206
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1087
#     BS is: 0.0285
#
# === Grid 109/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1164
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1167
#     BS is: 0.0306
#   Fold 3/4
#     LL is: 0.1259
#     BS is: 0.0327
#   Fold 4/4
#     LL is: 0.1132
#     BS is: 0.0287
#
# === Grid 110/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1166
#     BS is: 0.0304
#   Fold 2/4
#     LL is: 0.1142
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1223
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1112
#     BS is: 0.0289
#
# === Grid 111/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1153
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1115
#     BS is: 0.0289
#
# === Grid 112/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1147
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1217
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0284
#
# === Grid 113/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1145
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0284
#
# === Grid 114/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1140
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0286
#
# === Grid 115/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1165
#     BS is: 0.0305
#   Fold 2/4
#     LL is: 0.1162
#     BS is: 0.0307
#   Fold 3/4
#     LL is: 0.1229
#     BS is: 0.0325
#   Fold 4/4
#     LL is: 0.1134
#     BS is: 0.0295
#
# === Grid 116/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1138
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1141
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1112
#     BS is: 0.0289
#
# === Grid 117/162:  batch_size=800,  epochs=30, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1139
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0287
#
# === Grid 118/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1164
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1162
#     BS is: 0.0308
#   Fold 3/4
#     LL is: 0.1234
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1116
#     BS is: 0.0291
#
# === Grid 119/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1146
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1150
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1217
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1099
#     BS is: 0.0285
#
# === Grid 120/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1159
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1151
#     BS is: 0.0305
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1126
#     BS is: 0.0286
#
# === Grid 121/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1168
#     BS is: 0.0304
#   Fold 2/4
#     LL is: 0.1175
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1220
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0287
#
# === Grid 122/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1159
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1119
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1202
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1094
#     BS is: 0.0284
#
# === Grid 123/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1134
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1216
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1088
#     BS is: 0.0284
#
# === Grid 124/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1141
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1126
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1240
#     BS is: 0.0329
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0286
#
# === Grid 125/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1137
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1116
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1110
#     BS is: 0.0290
#
# === Grid 126/162:  batch_size=800,  epochs=30, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1119
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1097
#     BS is: 0.0287
#
# === Grid 127/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1142
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1120
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1127
#     BS is: 0.0294
#
# === Grid 128/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1140
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1199
#     BS is: 0.0316
#   Fold 4/4
#     LL is: 0.1103
#     BS is: 0.0288
#
# === Grid 129/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1146
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1213
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0285
#
# === Grid 130/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1140
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1131
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1238
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0285
#
# === Grid 131/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1129
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0285
#
# === Grid 132/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1125
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1198
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0288
#
# === Grid 133/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1148
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1118
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1256
#     BS is: 0.0332
#   Fold 4/4
#     LL is: 0.1116
#     BS is: 0.0292
#
# === Grid 134/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1130
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1115
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1202
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0288
#
# === Grid 135/162:  batch_size=800,  epochs=30, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1213
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1094
#     BS is: 0.0287
#
# === Grid 136/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1185
#     BS is: 0.0309
#   Fold 2/4
#     LL is: 0.1176
#     BS is: 0.0311
#   Fold 3/4
#     LL is: 0.1307
#     BS is: 0.0336
#   Fold 4/4
#     LL is: 0.1149
#     BS is: 0.0296
#
# === Grid 137/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1144
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1161
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0286
#
# === Grid 138/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1154
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1221
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0286
#
# === Grid 139/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1144
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1127
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0287
#
# === Grid 140/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1140
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1148
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0286
#
# === Grid 141/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1151
#     BS is: 0.0300
#   Fold 2/4
#     LL is: 0.1120
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1205
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0285
#
# === Grid 142/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1152
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1138
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1268
#     BS is: 0.0333
#   Fold 4/4
#     LL is: 0.1105
#     BS is: 0.0289
#
# === Grid 143/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1135
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1138
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0318
#   Fold 4/4
#     LL is: 0.1100
#     BS is: 0.0287
#
# === Grid 144/162:  batch_size=800,  epochs=60, lr=0.001, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1162
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1135
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1206
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1137
#     BS is: 0.0292
#
# === Grid 145/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1173
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1226
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1120
#     BS is: 0.0291
#
# === Grid 146/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1155
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1151
#     BS is: 0.0307
#   Fold 3/4
#     LL is: 0.1222
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1109
#     BS is: 0.0286
#
# === Grid 147/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1147
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1142
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1218
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1095
#     BS is: 0.0285
#
# === Grid 148/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1139
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1165
#     BS is: 0.0305
#   Fold 3/4
#     LL is: 0.1214
#     BS is: 0.0322
#   Fold 4/4
#     LL is: 0.1088
#     BS is: 0.0284
#
# === Grid 149/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1143
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1128
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1235
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1099
#     BS is: 0.0286
#
# === Grid 150/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0302
#   Fold 3/4
#     LL is: 0.1196
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1105
#     BS is: 0.0289
#
# === Grid 151/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1124
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1223
#     BS is: 0.0326
#   Fold 4/4
#     LL is: 0.1111
#     BS is: 0.0290
#
# === Grid 152/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1134
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1150
#     BS is: 0.0304
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0319
#   Fold 4/4
#     LL is: 0.1124
#     BS is: 0.0293
#
# === Grid 153/162:  batch_size=800,  epochs=60, lr=0.005, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1131
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1123
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1209
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1093
#     BS is: 0.0286
#
# === Grid 154/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.0, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1162
#     BS is: 0.0303
#   Fold 2/4
#     LL is: 0.1165
#     BS is: 0.0307
#   Fold 3/4
#     LL is: 0.1215
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1127
#     BS is: 0.0292
#
# === Grid 155/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.0, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1159
#     BS is: 0.0302
#   Fold 2/4
#     LL is: 0.1136
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1236
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1114
#     BS is: 0.0287
#
# === Grid 156/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.0, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1150
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1137
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1224
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1101
#     BS is: 0.0288
#
# === Grid 157/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.2, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1130
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1118
#     BS is: 0.0298
#   Fold 3/4
#     LL is: 0.1212
#     BS is: 0.0321
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0285
#
# === Grid 158/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.2, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1147
#     BS is: 0.0301
#   Fold 2/4
#     LL is: 0.1130
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1201
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1092
#     BS is: 0.0285
#
# === Grid 159/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.2, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1132
#     BS is: 0.0298
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0301
#   Fold 3/4
#     LL is: 0.1232
#     BS is: 0.0324
#   Fold 4/4
#     LL is: 0.1096
#     BS is: 0.0287
#
# === Grid 160/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.5, nodes=[32, 16] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1134
#     BS is: 0.0303
#   Fold 3/4
#     LL is: 0.1210
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1097
#     BS is: 0.0286
#
# === Grid 161/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.5, nodes=[32] ===
#   Fold 1/4
#     LL is: 0.1133
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1119
#     BS is: 0.0299
#   Fold 3/4
#     LL is: 0.1197
#     BS is: 0.0317
#   Fold 4/4
#     LL is: 0.1091
#     BS is: 0.0284
#
# === Grid 162/162:  batch_size=800,  epochs=60, lr=0.01, dropout=0.5, nodes=[16] ===
#   Fold 1/4
#     LL is: 0.1131
#     BS is: 0.0299
#   Fold 2/4
#     LL is: 0.1122
#     BS is: 0.0300
#   Fold 3/4
#     LL is: 0.1207
#     BS is: 0.0320
#   Fold 4/4
#     LL is: 0.1089
#     BS is: 0.0285

# %%
# report best result from best to worst

results_ll_df = pd.DataFrame(results_ll)
results_ll_df['ll3y'] = - results_ll_df['mean_neg_logloss']

print(results_ll_df.sort_values(by='mean_neg_logloss', ascending=False).to_string(index=False))
# Out:
#  batch_size  epochs    lr  dropout num_nodes  mean_neg_logloss  std_neg_logloss     ll3y
#         400      60 0.005      0.5      [32]         -0.113353         0.004041 0.113353
#         800      60 0.010      0.5      [32]         -0.113501         0.003860 0.113501
#         200      30 0.005      0.5      [32]         -0.113556         0.003872 0.113556
#         400      60 0.010      0.5      [16]         -0.113644         0.004373 0.113644
#         400      60 0.010      0.5      [32]         -0.113675         0.004812 0.113675
#         200      60 0.001      0.5      [32]         -0.113693         0.003467 0.113693
#         800      30 0.010      0.5      [32]         -0.113710         0.003880 0.113710
#         400      30 0.010      0.2      [32]         -0.113720         0.004187 0.113720
#         200      60 0.001      0.2      [16]         -0.113721         0.003815 0.113721
#         800      60 0.010      0.5      [16]         -0.113722         0.004343 0.113722
#         200      30 0.010      0.5      [16]         -0.113730         0.003781 0.113730
#         800      60 0.010      0.2  [32, 16]         -0.113769         0.004503 0.113769
#         400      60 0.005      0.5      [16]         -0.113817         0.004199 0.113817
#         400      30 0.010      0.5      [16]         -0.113841         0.004052 0.113841
#         200      60 0.005      0.5      [16]         -0.113856         0.004191 0.113856
#         400      30 0.010      0.2      [16]         -0.113864         0.003789 0.113864
#         800      60 0.005      0.5      [16]         -0.113897         0.004270 0.113897
#         400      30 0.010      0.2  [32, 16]         -0.113907         0.004638 0.113907
#         200      30 0.005      0.5      [16]         -0.113909         0.004065 0.113909
#         400      30 0.001      0.2      [16]         -0.113916         0.004002 0.113916
#         800      30 0.010      0.2      [16]         -0.113928         0.003560 0.113928
#         200      30 0.010      0.5      [32]         -0.113943         0.004480 0.113943
#         200      60 0.005      0.5  [32, 16]         -0.113958         0.003845 0.113958
#         400      60 0.010      0.2      [32]         -0.113985         0.003585 0.113985
#         400      30 0.010      0.5  [32, 16]         -0.113999         0.004614 0.113999
#         400      30 0.005      0.2      [32]         -0.114002         0.004281 0.114002
#         800      30 0.010      0.5      [16]         -0.114006         0.004427 0.114006
#         200      30 0.010      0.5  [32, 16]         -0.114006         0.004224 0.114006
#         400      30 0.005      0.2      [16]         -0.114024         0.004354 0.114024
#         400      60 0.005      0.2      [16]         -0.114037         0.004203 0.114037
#         800      30 0.005      0.5      [16]         -0.114041         0.004406 0.114041
#         400      60 0.001      0.2      [32]         -0.114054         0.004411 0.114054
#         200      60 0.005      0.2      [16]         -0.114075         0.004706 0.114075
#         400      30 0.005      0.5      [32]         -0.114088         0.003884 0.114088
#         400      30 0.010      0.5      [32]         -0.114125         0.004747 0.114125
#         200      30 0.010      0.2      [16]         -0.114158         0.004196 0.114158
#         400      60 0.010      0.2      [16]         -0.114159         0.004489 0.114159
#         200      30 0.001      0.5      [16]         -0.114167         0.003727 0.114167
#         400      60 0.001      0.2      [16]         -0.114183         0.003695 0.114183
#         800      30 0.010      0.2      [32]         -0.114186         0.004476 0.114186
#         800      30 0.001      0.2      [16]         -0.114213         0.004278 0.114213
#         200      60 0.010      0.2      [16]         -0.114220         0.004058 0.114220
#         800      60 0.001      0.2      [16]         -0.114227         0.004177 0.114227
#         800      60 0.010      0.2      [32]         -0.114229         0.003908 0.114229
#         800      60 0.005      0.2      [16]         -0.114276         0.003326 0.114276
#         200      60 0.010      0.5      [16]         -0.114276         0.003909 0.114276
#         200      60 0.005      0.5      [32]         -0.114277         0.004013 0.114277
#         800      30 0.005      0.2      [16]         -0.114280         0.004639 0.114280
#         800      30 0.001      0.2      [32]         -0.114306         0.004473 0.114306
#         200      60 0.010      0.5      [32]         -0.114307         0.004128 0.114307
#         800      30 0.005      0.5      [32]         -0.114323         0.003952 0.114323
#         200      30 0.005      0.2      [32]         -0.114325         0.003977 0.114325
#         400      30 0.001      0.2      [32]         -0.114339         0.004540 0.114339
#         800      30 0.005      0.2      [32]         -0.114339         0.004090 0.114339
#         800      60 0.010      0.5  [32, 16]         -0.114360         0.004103 0.114360
#         200      60 0.010      0.0      [16]         -0.114360         0.003898 0.114360
#         200      30 0.010      0.2  [32, 16]         -0.114388         0.003964 0.114388
#         800      30 0.001      0.5      [16]         -0.114401         0.004070 0.114401
#         200      30 0.001      0.2      [32]         -0.114410         0.004372 0.114410
#         400      60 0.005      0.5  [32, 16]         -0.114424         0.004570 0.114424
#         200      30 0.001      0.0      [16]         -0.114428         0.003904 0.114428
#         400      30 0.001      0.5      [32]         -0.114428         0.003576 0.114428
#         200      60 0.010      0.2      [32]         -0.114429         0.003950 0.114429
#         200      60 0.001      0.2      [32]         -0.114446         0.004262 0.114446
#         800      30 0.010      0.0      [32]         -0.114448         0.003469 0.114448
#         400      30 0.001      0.5      [16]         -0.114477         0.003646 0.114477
#         800      60 0.001      0.5      [32]         -0.114494         0.003858 0.114494
#         200      60 0.005      0.2  [32, 16]         -0.114501         0.004508 0.114501
#         400      60 0.010      0.5  [32, 16]         -0.114535         0.004070 0.114535
#         800      60 0.010      0.2      [16]         -0.114544         0.005172 0.114544
#         400      60 0.010      0.2  [32, 16]         -0.114559         0.004072 0.114559
#         200      60 0.010      0.2  [32, 16]         -0.114570         0.004128 0.114570
#         400      60 0.005      0.2  [32, 16]         -0.114605         0.005083 0.114605
#         400      60 0.010      0.0      [32]         -0.114629         0.003709 0.114629
#         800      60 0.001      0.2  [32, 16]         -0.114661         0.004171 0.114661
#         200      60 0.010      0.5  [32, 16]         -0.114661         0.003940 0.114661
#         400      60 0.001      0.2  [32, 16]         -0.114685         0.003692 0.114685
#         800      30 0.010      0.0      [16]         -0.114687         0.004332 0.114687
#         400      30 0.005      0.5  [32, 16]         -0.114694         0.004732 0.114694
#         400      30 0.001      0.0      [16]         -0.114731         0.004199 0.114731
#         400      60 0.010      0.0  [32, 16]         -0.114772         0.004546 0.114772
#         800      60 0.001      0.2      [32]         -0.114790         0.004051 0.114790
#         800      60 0.005      0.5  [32, 16]         -0.114811         0.004396 0.114811
#         400      60 0.010      0.0      [16]         -0.114821         0.004138 0.114821
#         400      30 0.005      0.5      [16]         -0.114831         0.005053 0.114831
#         400      60 0.001      0.5      [16]         -0.114834         0.003959 0.114834
#         200      30 0.001      0.2      [16]         -0.114836         0.004394 0.114836
#         200      30 0.010      0.0  [32, 16]         -0.114844         0.003705 0.114844
#         400      60 0.001      0.5      [32]         -0.114871         0.005410 0.114871
#         800      30 0.001      0.2  [32, 16]         -0.114880         0.004415 0.114880
#         200      30 0.010      0.0      [16]         -0.114884         0.003883 0.114884
#         400      30 0.010      0.0      [16]         -0.114899         0.004446 0.114899
#         200      60 0.001      0.5      [16]         -0.114914         0.004561 0.114914
#         800      30 0.010      0.0  [32, 16]         -0.114914         0.003445 0.114914
#         200      30 0.001      0.2  [32, 16]         -0.114932         0.005538 0.114932
#         200      60 0.005      0.2      [32]         -0.114958         0.003750 0.114958
#         800      30 0.010      0.2  [32, 16]         -0.114976         0.005433 0.114976
#         200      30 0.005      0.0      [32]         -0.114986         0.004000 0.114986
#         400      60 0.001      0.0      [16]         -0.114992         0.004307 0.114992
#         800      30 0.001      0.0      [16]         -0.115001         0.003444 0.115001
#         800      60 0.005      0.0      [16]         -0.115040         0.004391 0.115040
#         400      30 0.005      0.0      [16]         -0.115046         0.003360 0.115046
#         200      60 0.010      0.0      [32]         -0.115048         0.003866 0.115048
#         800      30 0.001      0.5      [32]         -0.115066         0.003746 0.115066
#         800      60 0.005      0.2      [32]         -0.115122         0.005090 0.115122
#         200      30 0.010      0.2      [32]         -0.115153         0.004442 0.115153
#         800      60 0.005      0.2  [32, 16]         -0.115173         0.004544 0.115173
#         800      30 0.005      0.5  [32, 16]         -0.115180         0.005283 0.115180
#         800      60 0.001      0.0      [16]         -0.115213         0.004482 0.115213
#         800      60 0.005      0.5      [32]         -0.115213         0.002987 0.115213
#         400      60 0.005      0.0      [16]         -0.115217         0.004549 0.115217
#         200      30 0.001      0.0      [32]         -0.115294         0.004893 0.115294
#         800      60 0.010      0.0      [16]         -0.115309         0.004477 0.115309
#         200      30 0.005      0.0      [16]         -0.115317         0.005295 0.115317
#         800      30 0.005      0.0      [32]         -0.115333         0.004189 0.115333
#         800      60 0.001      0.0      [32]         -0.115337         0.003901 0.115337
#         200      30 0.005      0.2      [16]         -0.115459         0.006178 0.115459
#         400      30 0.010      0.0  [32, 16]         -0.115542         0.004839 0.115542
#         200      30 0.005      0.5  [32, 16]         -0.115582         0.004175 0.115582
#         200      60 0.001      0.2  [32, 16]         -0.115599         0.005094 0.115599
#         400      30 0.001      0.2  [32, 16]         -0.115635         0.003778 0.115635
#         400      30 0.001      0.0      [32]         -0.115651         0.004475 0.115651
#         200      30 0.010      0.0      [32]         -0.115804         0.004678 0.115804
#         200      60 0.001      0.0      [16]         -0.115815         0.004303 0.115815
#         200      60 0.005      0.0      [16]         -0.115876         0.004329 0.115876
#         400      30 0.005      0.2  [32, 16]         -0.115877         0.003906 0.115877
#         800      60 0.005      0.0      [32]         -0.115923         0.004049 0.115923
#         800      30 0.010      0.5  [32, 16]         -0.115966         0.005710 0.115966
#         800      60 0.001      0.5      [16]         -0.116028         0.002874 0.116028
#         800      30 0.005      0.0      [16]         -0.116028         0.002874 0.116028
#         400      30 0.010      0.0      [32]         -0.116036         0.003239 0.116036
#         200      60 0.010      0.0  [32, 16]         -0.116049         0.004362 0.116049
#         800      30 0.001      0.0      [32]         -0.116071         0.004082 0.116071
#         400      60 0.005      0.2      [32]         -0.116074         0.005439 0.116074
#         800      60 0.010      0.0      [32]         -0.116101         0.004599 0.116101
#         200      30 0.001      0.5  [32, 16]         -0.116111         0.004871 0.116111
#         200      30 0.005      0.0  [32, 16]         -0.116152         0.005246 0.116152
#         400      60 0.001      0.0      [32]         -0.116336         0.004750 0.116336
#         800      60 0.005      0.0  [32, 16]         -0.116404         0.004069 0.116404
#         200      30 0.005      0.2  [32, 16]         -0.116407         0.004746 0.116407
#         200      60 0.001      0.0  [32, 16]         -0.116427         0.004241 0.116427
#         800      30 0.005      0.2  [32, 16]         -0.116448         0.004443 0.116448
#         400      60 0.005      0.0  [32, 16]         -0.116520         0.003558 0.116520
#         400      60 0.001      0.5  [32, 16]         -0.116521         0.003314 0.116521
#         800      60 0.001      0.5  [32, 16]         -0.116566         0.006138 0.116566
#         400      30 0.005      0.0  [32, 16]         -0.116683         0.004502 0.116683
#         800      60 0.010      0.0  [32, 16]         -0.116723         0.003146 0.116723
#         200      60 0.001      0.0      [32]         -0.116825         0.005941 0.116825
#         800      30 0.005      0.0  [32, 16]         -0.116901         0.004209 0.116901
#         200      30 0.001      0.5      [32]         -0.116965         0.002798 0.116965
#         400      60 0.001      0.0  [32, 16]         -0.117026         0.004473 0.117026
#         200      60 0.005      0.0      [32]         -0.117029         0.003721 0.117029
#         400      30 0.005      0.0      [32]         -0.117121         0.002345 0.117121
#         400      30 0.001      0.5  [32, 16]         -0.117162         0.003982 0.117162
#         800      30 0.001      0.5  [32, 16]         -0.117253         0.003487 0.117253
#         400      30 0.001      0.0  [32, 16]         -0.117275         0.003814 0.117275
#         200      60 0.005      0.0  [32, 16]         -0.117377         0.006245 0.117377
#         400      60 0.005      0.0      [32]         -0.117415         0.003942 0.117415
#         200      30 0.001      0.0  [32, 16]         -0.117833         0.005810 0.117833
#         200      60 0.001      0.5  [32, 16]         -0.117887         0.006141 0.117887
#         800      30 0.001      0.0  [32, 16]         -0.118038         0.004751 0.118038
#         800      60 0.001      0.0  [32, 16]         -0.120457         0.006070 0.120457

# %%
results_bs_df = pd.DataFrame(results_bs)
results_bs_df['bs3y'] = - results_bs_df['mean_neg_logloss']

print(results_bs_df.sort_values(by='mean_neg_logloss', ascending=False).to_string(index=False))

# %%
#______________________________________________________________________________________________________________________________

# %%
#______________________________________________________________________________________________________________________________

# %%
# DeepSC1L

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED) 
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(SEED)

# define the network
in_features = x_train.shape[1]
net = tt.practical.MLPVanilla(in_features, [32], 1, activation=nn.ReLU, dropout=0.5)

# model and optimizer

loss_fn = nn.BCEWithLogitsLoss()
model = tt.Model(net, loss_fn, tt.optim.Adam) 
model.optimizer.set_lr(0.005) 

# training setup     
batch_size = 400
epochs = 60
# for early stoping
checkpoint_path = 'best_model.pt'
if os.path.exists(checkpoint_path):
    os.remove(checkpoint_path)
callbacks = [EarlyStopping(patience=20, file_path=checkpoint_path)]

# fit 
log = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, val_data=(x_test, y_test), shuffle=True,
                callbacks=callbacks, verbose=True)
# Out:
# 0:	[0s / 0s],		train_loss: 0.2593,	val_loss: 0.1119
# 1:	[0s / 0s],		train_loss: 0.1250,	val_loss: 0.1098
# 2:	[0s / 0s],		train_loss: 0.1202,	val_loss: 0.1092
# 3:	[0s / 1s],		train_loss: 0.1184,	val_loss: 0.1087
# 4:	[0s / 1s],		train_loss: 0.1177,	val_loss: 0.1086
# 5:	[0s / 1s],		train_loss: 0.1163,	val_loss: 0.1083
# 6:	[0s / 2s],		train_loss: 0.1167,	val_loss: 0.1084
# 7:	[0s / 2s],		train_loss: 0.1161,	val_loss: 0.1084
# 8:	[0s / 2s],		train_loss: 0.1155,	val_loss: 0.1081
# 9:	[0s / 3s],		train_loss: 0.1159,	val_loss: 0.1081
# 10:	[0s / 3s],		train_loss: 0.1150,	val_loss: 0.1079
# 11:	[0s / 3s],		train_loss: 0.1153,	val_loss: 0.1084
# 12:	[0s / 3s],		train_loss: 0.1149,	val_loss: 0.1080
# 13:	[0s / 4s],		train_loss: 0.1149,	val_loss: 0.1077
# 14:	[0s / 4s],		train_loss: 0.1150,	val_loss: 0.1077
# 15:	[0s / 4s],		train_loss: 0.1144,	val_loss: 0.1079
# 16:	[0s / 5s],		train_loss: 0.1145,	val_loss: 0.1079
# 17:	[0s / 5s],		train_loss: 0.1144,	val_loss: 0.1078
# 18:	[0s / 5s],		train_loss: 0.1140,	val_loss: 0.1078
# 19:	[0s / 5s],		train_loss: 0.1137,	val_loss: 0.1082
# 20:	[0s / 6s],		train_loss: 0.1138,	val_loss: 0.1081
# 21:	[0s / 6s],		train_loss: 0.1142,	val_loss: 0.1080
# 22:	[0s / 6s],		train_loss: 0.1138,	val_loss: 0.1078
# 23:	[0s / 7s],		train_loss: 0.1137,	val_loss: 0.1076
# 24:	[0s / 7s],		train_loss: 0.1137,	val_loss: 0.1075
# 25:	[0s / 7s],		train_loss: 0.1130,	val_loss: 0.1075
# 26:	[0s / 8s],		train_loss: 0.1127,	val_loss: 0.1076
# 27:	[0s / 8s],		train_loss: 0.1132,	val_loss: 0.1075
# 28:	[0s / 8s],		train_loss: 0.1129,	val_loss: 0.1076
# 29:	[0s / 9s],		train_loss: 0.1124,	val_loss: 0.1087
# 30:	[0s / 9s],		train_loss: 0.1130,	val_loss: 0.1080
# 31:	[0s / 9s],		train_loss: 0.1131,	val_loss: 0.1095
# 32:	[0s / 9s],		train_loss: 0.1129,	val_loss: 0.1085
# 33:	[0s / 10s],		train_loss: 0.1129,	val_loss: 0.1077
# 34:	[0s / 10s],		train_loss: 0.1129,	val_loss: 0.1084
# 35:	[0s / 11s],		train_loss: 0.1127,	val_loss: 0.1078
# 36:	[0s / 11s],		train_loss: 0.1132,	val_loss: 0.1078
# 37:	[0s / 11s],		train_loss: 0.1121,	val_loss: 0.1078
# 38:	[0s / 11s],		train_loss: 0.1128,	val_loss: 0.1077
# 39:	[0s / 12s],		train_loss: 0.1123,	val_loss: 0.1082
# 40:	[0s / 12s],		train_loss: 0.1126,	val_loss: 0.1079
# 41:	[0s / 12s],		train_loss: 0.1125,	val_loss: 0.1079
# 42:	[0s / 13s],		train_loss: 0.1112,	val_loss: 0.1083
# 43:	[0s / 13s],		train_loss: 0.1113,	val_loss: 0.1082
# 44:	[0s / 13s],		train_loss: 0.1120,	val_loss: 0.1081
# 45:	[0s / 13s],		train_loss: 0.1121,	val_loss: 0.1082

# %%
log.plot()
# Out:
# <Axes: >

# %%
# get probabilites
probs_train = torch.sigmoid(model.predict(x_train))
probs_test = torch.sigmoid(model.predict(x_test))

print(f'log-loss is: {log_loss(y_train, probs_train):.4f}')
print(f'log-loss os: {log_loss(y_test, probs_test):.4f}')
print(f'BS is: {brier_score_loss(y_train, probs_train):.4f}')
print(f'BS os: {brier_score_loss(y_test, probs_test):.4f}')
# Out:
# log-loss is: 0.1089
# log-loss os: 0.1090
# BS is: 0.0290
# BS os: 0.0290

# %%
# DeepSC2L

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(SEED)

# define the network
in_features = x_train.shape[1]
net = tt.practical.MLPVanilla(in_features, [32], 1, activation=nn.ReLU, dropout=0.5)

# model and optimizer
loss_fn = nn.BCEWithLogitsLoss()
model = tt.Model(net, loss_fn, tt.optim.Adam)  
model.optimizer.set_lr(0.010)  

# training setup     
batch_size = 800
epochs = 60
# for early stopping
checkpoint_path = 'best_model.pt'
if os.path.exists(checkpoint_path):
    os.remove(checkpoint_path)
callbacks = [EarlyStopping(patience=20, file_path=checkpoint_path)]

# fit
log = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, val_data=(x_test, y_test), shuffle=True,
                callbacks=callbacks, verbose=True)
# Out:
# 0:	[0s / 0s],		train_loss: 0.2632,	val_loss: 0.1127
# 1:	[0s / 0s],		train_loss: 0.1220,	val_loss: 0.1098
# 2:	[0s / 0s],		train_loss: 0.1188,	val_loss: 0.1094
# 3:	[0s / 0s],		train_loss: 0.1169,	val_loss: 0.1087
# 4:	[0s / 0s],		train_loss: 0.1166,	val_loss: 0.1086
# 5:	[0s / 1s],		train_loss: 0.1163,	val_loss: 0.1086
# 6:	[0s / 1s],		train_loss: 0.1165,	val_loss: 0.1080
# 7:	[0s / 1s],		train_loss: 0.1152,	val_loss: 0.1080
# 8:	[0s / 1s],		train_loss: 0.1157,	val_loss: 0.1079
# 9:	[0s / 2s],		train_loss: 0.1156,	val_loss: 0.1076
# 10:	[0s / 2s],		train_loss: 0.1150,	val_loss: 0.1076
# 11:	[0s / 2s],		train_loss: 0.1153,	val_loss: 0.1078
# 12:	[0s / 2s],		train_loss: 0.1152,	val_loss: 0.1086
# 13:	[0s / 3s],		train_loss: 0.1147,	val_loss: 0.1078
# 14:	[0s / 3s],		train_loss: 0.1150,	val_loss: 0.1078
# 15:	[0s / 3s],		train_loss: 0.1144,	val_loss: 0.1076
# 16:	[0s / 3s],		train_loss: 0.1142,	val_loss: 0.1075
# 17:	[0s / 3s],		train_loss: 0.1145,	val_loss: 0.1078
# 18:	[0s / 4s],		train_loss: 0.1137,	val_loss: 0.1077
# 19:	[0s / 4s],		train_loss: 0.1135,	val_loss: 0.1080
# 20:	[0s / 4s],		train_loss: 0.1136,	val_loss: 0.1074
# 21:	[0s / 4s],		train_loss: 0.1140,	val_loss: 0.1079
# 22:	[0s / 5s],		train_loss: 0.1138,	val_loss: 0.1072
# 23:	[0s / 5s],		train_loss: 0.1139,	val_loss: 0.1072
# 24:	[0s / 5s],		train_loss: 0.1132,	val_loss: 0.1072
# 25:	[0s / 5s],		train_loss: 0.1128,	val_loss: 0.1074
# 26:	[0s / 6s],		train_loss: 0.1135,	val_loss: 0.1076
# 27:	[0s / 6s],		train_loss: 0.1138,	val_loss: 0.1080
# 28:	[0s / 6s],		train_loss: 0.1132,	val_loss: 0.1073
# 29:	[0s / 6s],		train_loss: 0.1130,	val_loss: 0.1071
# 30:	[0s / 7s],		train_loss: 0.1133,	val_loss: 0.1073
# 31:	[0s / 7s],		train_loss: 0.1127,	val_loss: 0.1082
# 32:	[0s / 7s],		train_loss: 0.1128,	val_loss: 0.1075
# 33:	[0s / 8s],		train_loss: 0.1129,	val_loss: 0.1074
# 34:	[0s / 8s],		train_loss: 0.1124,	val_loss: 0.1075
# 35:	[0s / 8s],		train_loss: 0.1127,	val_loss: 0.1071
# 36:	[0s / 8s],		train_loss: 0.1122,	val_loss: 0.1073
# 37:	[0s / 8s],		train_loss: 0.1121,	val_loss: 0.1075
# 38:	[0s / 9s],		train_loss: 0.1118,	val_loss: 0.1078
# 39:	[0s / 9s],		train_loss: 0.1124,	val_loss: 0.1073
# 40:	[0s / 9s],		train_loss: 0.1116,	val_loss: 0.1075
# 41:	[0s / 10s],		train_loss: 0.1124,	val_loss: 0.1075
# 42:	[0s / 10s],		train_loss: 0.1121,	val_loss: 0.1087
# 43:	[0s / 10s],		train_loss: 0.1118,	val_loss: 0.1073
# 44:	[0s / 10s],		train_loss: 0.1113,	val_loss: 0.1075
# 45:	[0s / 11s],		train_loss: 0.1113,	val_loss: 0.1075
# 46:	[0s / 11s],		train_loss: 0.1113,	val_loss: 0.1075
# 47:	[0s / 11s],		train_loss: 0.1114,	val_loss: 0.1076
# 48:	[0s / 12s],		train_loss: 0.1113,	val_loss: 0.1081
# 49:	[0s / 12s],		train_loss: 0.1118,	val_loss: 0.1075

# %%
log.plot()
# Out:
# <Axes: >

# %%
# get probabilites
probs_train = torch.sigmoid(model.predict(x_train))
probs_test = torch.sigmoid(model.predict(x_test))

print(f'log-loss is: {log_loss(y_train, probs_train):.4f}')
print(f'log-loss os: {log_loss(y_test, probs_test):.4f}')
print(f'BS is: {brier_score_loss(y_train, probs_train):.4f}')
print(f'BS os: {brier_score_loss(y_test, probs_test):.4f}')
# Out:
# log-loss is: 0.1088
# log-loss os: 0.1087
# BS is: 0.0289
# BS os: 0.0290

# %%
# DeepSC3L

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(SEED)

# define the network
in_features = x_train.shape[1]
net = tt.practical.MLPVanilla(in_features, [32], 1, activation=nn.ReLU, dropout=0.5)

# model and optimizer=
loss_fn = nn.BCEWithLogitsLoss()
model = tt.Model(net, loss_fn, tt.optim.Adam)  
model.optimizer.set_lr(0.005)  

# training setup 
batch_size = 200
epochs = 30
# for early stopping
checkpoint_path = 'best_model.pt'
if os.path.exists(checkpoint_path):
    os.remove(checkpoint_path)
callbacks = [EarlyStopping(patience=20, file_path=checkpoint_path)]

# fit
log = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, val_data=(x_test, y_test), shuffle=True,
                callbacks=callbacks, verbose=True)
# Out:
# 0:	[0s / 0s],		train_loss: 0.1991,	val_loss: 0.1127
# 1:	[0s / 1s],		train_loss: 0.1211,	val_loss: 0.1113
# 2:	[0s / 2s],		train_loss: 0.1187,	val_loss: 0.1101
# 3:	[0s / 3s],		train_loss: 0.1168,	val_loss: 0.1101
# 4:	[0s / 3s],		train_loss: 0.1172,	val_loss: 0.1090
# 5:	[0s / 4s],		train_loss: 0.1163,	val_loss: 0.1081
# 6:	[0s / 5s],		train_loss: 0.1161,	val_loss: 0.1088
# 7:	[0s / 6s],		train_loss: 0.1155,	val_loss: 0.1081
# 8:	[0s / 6s],		train_loss: 0.1162,	val_loss: 0.1080
# 9:	[0s / 7s],		train_loss: 0.1153,	val_loss: 0.1095
# 10:	[0s / 7s],		train_loss: 0.1151,	val_loss: 0.1076
# 11:	[0s / 8s],		train_loss: 0.1150,	val_loss: 0.1079
# 12:	[0s / 9s],		train_loss: 0.1149,	val_loss: 0.1079
# 13:	[0s / 9s],		train_loss: 0.1144,	val_loss: 0.1082
# 14:	[0s / 10s],		train_loss: 0.1141,	val_loss: 0.1083
# 15:	[0s / 11s],		train_loss: 0.1144,	val_loss: 0.1083
# 16:	[0s / 11s],		train_loss: 0.1142,	val_loss: 0.1080
# 17:	[0s / 12s],		train_loss: 0.1143,	val_loss: 0.1085
# 18:	[0s / 12s],		train_loss: 0.1140,	val_loss: 0.1080
# 19:	[0s / 13s],		train_loss: 0.1135,	val_loss: 0.1074
# 20:	[0s / 14s],		train_loss: 0.1144,	val_loss: 0.1079
# 21:	[0s / 14s],		train_loss: 0.1136,	val_loss: 0.1081
# 22:	[0s / 15s],		train_loss: 0.1135,	val_loss: 0.1078
# 23:	[0s / 16s],		train_loss: 0.1133,	val_loss: 0.1083
# 24:	[0s / 16s],		train_loss: 0.1136,	val_loss: 0.1080
# 25:	[0s / 17s],		train_loss: 0.1132,	val_loss: 0.1077
# 26:	[0s / 18s],		train_loss: 0.1137,	val_loss: 0.1082
# 27:	[0s / 18s],		train_loss: 0.1135,	val_loss: 0.1080
# 28:	[0s / 19s],		train_loss: 0.1131,	val_loss: 0.1079
# 29:	[0s / 19s],		train_loss: 0.1138,	val_loss: 0.1081

# %%
log.plot()
# Out:
# <Axes: >

# %%
# get probabilites
probs_train = torch.sigmoid(model.predict(x_train))
probs_test = torch.sigmoid(model.predict(x_test))

print(f'log-loss is: {log_loss(y_train, probs_train):.4f}')
print(f'log-loss os: {log_loss(y_test, probs_test):.4f}')
print(f'BS is: {brier_score_loss(y_train, probs_train):.4f}')
print(f'BS os: {brier_score_loss(y_test, probs_test):.4f}')
# Out:
# log-loss is: 0.1094
# log-loss os: 0.1089
# BS is: 0.0291
# BS os: 0.0290

# %%
#______________________________________________________________________________________________________________________________

# %%
# DeepSC3B

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(SEED)

# define the network
in_features = x_train.shape[1]
net = tt.practical.MLPVanilla(in_features, [16], 1, activation=nn.ReLU, dropout=0.0)

# model and optimizer
loss_fn = nn.BCEWithLogitsLoss()
model = tt.Model(net, loss_fn, tt.optim.Adam)  
model.optimizer.set_lr(0.010)  

# training setup   
batch_size = 200
epochs = 60
# early stopping
checkpoint_path = 'best_model.pt'
if os.path.exists(checkpoint_path):
    os.remove(checkpoint_path)
callbacks = [EarlyStopping(patience=20, file_path=checkpoint_path)]

# fit
log = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, val_data=(x_test, y_test), shuffle=True,
                callbacks=callbacks, verbose=True)
# Out:
# 0:	[0s / 0s],		train_loss: 0.1560,	val_loss: 0.1109
# 1:	[0s / 0s],		train_loss: 0.1146,	val_loss: 0.1097
# 2:	[0s / 1s],		train_loss: 0.1140,	val_loss: 0.1099
# 3:	[0s / 1s],		train_loss: 0.1135,	val_loss: 0.1100
# 4:	[0s / 2s],		train_loss: 0.1133,	val_loss: 0.1089
# 5:	[0s / 2s],		train_loss: 0.1126,	val_loss: 0.1091
# 6:	[0s / 3s],		train_loss: 0.1127,	val_loss: 0.1096
# 7:	[0s / 3s],		train_loss: 0.1126,	val_loss: 0.1094
# 8:	[0s / 4s],		train_loss: 0.1119,	val_loss: 0.1093
# 9:	[0s / 4s],		train_loss: 0.1115,	val_loss: 0.1105
# 10:	[0s / 5s],		train_loss: 0.1118,	val_loss: 0.1103
# 11:	[0s / 5s],		train_loss: 0.1112,	val_loss: 0.1087
# 12:	[0s / 6s],		train_loss: 0.1112,	val_loss: 0.1104
# 13:	[0s / 6s],		train_loss: 0.1108,	val_loss: 0.1084
# 14:	[0s / 7s],		train_loss: 0.1104,	val_loss: 0.1092
# 15:	[0s / 7s],		train_loss: 0.1109,	val_loss: 0.1095
# 16:	[0s / 8s],		train_loss: 0.1099,	val_loss: 0.1109
# 17:	[0s / 8s],		train_loss: 0.1101,	val_loss: 0.1094
# 18:	[0s / 9s],		train_loss: 0.1098,	val_loss: 0.1093
# 19:	[0s / 9s],		train_loss: 0.1101,	val_loss: 0.1090
# 20:	[0s / 10s],		train_loss: 0.1093,	val_loss: 0.1099
# 21:	[0s / 10s],		train_loss: 0.1098,	val_loss: 0.1096
# 22:	[0s / 11s],		train_loss: 0.1092,	val_loss: 0.1098
# 23:	[0s / 11s],		train_loss: 0.1095,	val_loss: 0.1097
# 24:	[0s / 12s],		train_loss: 0.1089,	val_loss: 0.1095
# 25:	[0s / 12s],		train_loss: 0.1091,	val_loss: 0.1096
# 26:	[0s / 13s],		train_loss: 0.1091,	val_loss: 0.1110
# 27:	[0s / 13s],		train_loss: 0.1091,	val_loss: 0.1105
# 28:	[0s / 14s],		train_loss: 0.1087,	val_loss: 0.1104
# 29:	[0s / 14s],		train_loss: 0.1088,	val_loss: 0.1114
# 30:	[0s / 15s],		train_loss: 0.1086,	val_loss: 0.1102
# 31:	[0s / 15s],		train_loss: 0.1084,	val_loss: 0.1106
# 32:	[0s / 16s],		train_loss: 0.1085,	val_loss: 0.1098
# 33:	[0s / 16s],		train_loss: 0.1081,	val_loss: 0.1103

# %%
log.plot()
# Out:
# <Axes: >

# %%
# get probabilites
probs_train = torch.sigmoid(model.predict(x_train))
probs_test = torch.sigmoid(model.predict(x_test))

print(f'log-loss is: {log_loss(y_train, probs_train):.4f}')
print(f'log-loss os: {log_loss(y_test, probs_test):.4f}')
print(f'BS is: {brier_score_loss(y_train, probs_train):.4f}')
print(f'BS os: {brier_score_loss(y_test, probs_test):.4f}')
# Out:
# log-loss is: 0.1085
# log-loss os: 0.1099
# BS is: 0.0288
# BS os: 0.0293
